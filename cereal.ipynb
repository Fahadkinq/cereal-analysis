# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cer=pd.read_csv('cereal.csv')

# %%
cer
# Out:
#                                       name mfr type  calories  protein  fat  \
# 0                                100% Bran   N    C        70        4    1
# 1                        100% Natural Bran   Q    C       120        3    5
# 2                                 All-Bran   K    C        70        4    1
# 3                All-Bran with Extra Fiber   K    C        50        4    0
# 4                           Almond Delight   R    C       110        2    2
# 5                  Apple Cinnamon Cheerios   G    C       110        2    2
# 6                              Apple Jacks   K    C       110        2    0
# 7                                  Basic 4   G    C       130        3    2
# 8                                Bran Chex   R    C        90        2    1
# 9                              Bran Flakes   P    C        90        3    0
# 10                            Cap'n'Crunch   Q    C       120        1    2
# ...

# %%
cer.head(10)
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6                Apple Jacks   K    C       110        2    0     125    1.0
# 7                    Basic 4   G    C       130        3    2     210    2.0
# 8                  Bran Chex   R    C        90        2    1     200    4.0
# 9                Bran Flakes   P    C        90        3    0     210    5.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# ...

# %%
cer.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
cer['mfr'].nunique()
# Out:
# 7

# %%
cer['name'].nunique()
# Out:
# 77

# %%
len(cer[cer['calories']>100])
# Out:
# 47

# %%
cer[cer['calories']>100].count()
# Out:
# name        47
# mfr         47
# type        47
# calories    47
# protein     47
# fat         47
# sodium      47
# fiber       47
# carbo       47
# sugars      47
# potass      47
# vitamins    47
# shelf       47
# weight      47
# cups        47
# rating      47
# dtype: int64

# %%
cer[cer['fiber']>5]['name']
# Out:
# 0                     100% Bran
# 2                      All-Bran
# 3     All-Bran with Extra Fiber
# 52        Post Nat. Raisin Bran
# Name: name, dtype: object

# %%
len(cer[(cer['name']=='Almond Delight') & (cer['sugars']<10)])
# Out:
# 1

# %%
cer[cer['name']=='Kelloggs']
# Out:
# Empty DataFrame
# Columns: [name, mfr, type, calories, protein, fat, sodium, fiber, carbo, sugars, potass, vitamins, shelf, weight, cups, rating]
# Index: []

# %%
cer.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
cer
# Out:
#                                       name mfr type  calories  protein  fat  \
# 0                                100% Bran   N    C        70        4    1
# 1                        100% Natural Bran   Q    C       120        3    5
# 2                                 All-Bran   K    C        70        4    1
# 3                All-Bran with Extra Fiber   K    C        50        4    0
# 4                           Almond Delight   R    C       110        2    2
# 5                  Apple Cinnamon Cheerios   G    C       110        2    2
# 6                              Apple Jacks   K    C       110        2    0
# 7                                  Basic 4   G    C       130        3    2
# 8                                Bran Chex   R    C        90        2    1
# 9                              Bran Flakes   P    C        90        3    0
# 10                            Cap'n'Crunch   Q    C       120        1    2
# ...

# %%
cer[(cer['rating']>60) & (cer['fat']<2)]
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 20     Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 54                Puffed Rice   Q    C        50        1    0       0    0.0
# 55               Puffed Wheat   Q    C        50        2    0       0    1.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3    1.00  0.33  68.402973
# 3     8.0       0     330        25      3    1.00  0.50  93.704912
# ...

# %%
len(cer['sugars'].notnull())
# Out:
# 77

# %%
cer.groupby('mfr')['calories'].mean()
# Out:
# mfr
# A    100.000000
# G    111.363636
# K    108.695652
# N     86.666667
# P    108.888889
# Q     95.000000
# R    115.000000
# Name: calories, dtype: float64

# %%
cer
# Out:
#                                       name mfr type  calories  protein  fat  \
# 0                                100% Bran   N    C        70        4    1
# 1                        100% Natural Bran   Q    C       120        3    5
# 2                                 All-Bran   K    C        70        4    1
# 3                All-Bran with Extra Fiber   K    C        50        4    0
# 4                           Almond Delight   R    C       110        2    2
# 5                  Apple Cinnamon Cheerios   G    C       110        2    2
# 6                              Apple Jacks   K    C       110        2    0
# 7                                  Basic 4   G    C       130        3    2
# 8                                Bran Chex   R    C        90        2    1
# 9                              Bran Flakes   P    C        90        3    0
# 10                            Cap'n'Crunch   Q    C       120        1    2
# ...

# %%
cer.groupby('shelf')['fiber'].sum()
# Out:
# shelf
# 1     33.7
# 2     19.0
# 3    113.0
# Name: fiber, dtype: float64

# %%
cer.groupby('vitamins')['rating'].mean()
# Out:
# vitamins
# 0      61.077283
# 25     40.762713
# 100    38.098352
# Name: rating, dtype: float64

# %%
cer.sort_values(by='rating',ascending=False)
# Out:
#                                  name mfr type  calories  protein  fat  \
# 3           All-Bran with Extra Fiber   K    C        50        4    0
# 64             Shredded Wheat 'n'Bran   N    C        90        3    0
# 65          Shredded Wheat spoon size   N    C        90        3    0
# 0                           100% Bran   N    C        70        4    1
# 63                     Shredded Wheat   N    C        80        2    0
# 20             Cream of Wheat (Quick)   N    H       100        3    0
# 55                       Puffed Wheat   Q    C        50        2    0
# 54                        Puffed Rice   Q    C        50        1    0
# 50                  Nutri-grain Wheat   K    C        90        3    0
# 2                            All-Bran   K    C        70        4    1
# 68            Strawberry Fruit Wheats   N    C        90        2    0
# 26                Frosted Mini-Wheats   K    C       100        3    0
# ...

# %%
cer.sort_values(by=['calories','sugars'],ascending=[True,True])
# Out:
#                                       name mfr type  calories  protein  fat  \
# 3                All-Bran with Extra Fiber   K    C        50        4    0
# 54                             Puffed Rice   Q    C        50        1    0
# 55                            Puffed Wheat   Q    C        50        2    0
# 2                                 All-Bran   K    C        70        4    1
# 0                                100% Bran   N    C        70        4    1
# 63                          Shredded Wheat   N    C        80        2    0
# 64                  Shredded Wheat 'n'Bran   N    C        90        3    0
# 65               Shredded Wheat spoon size   N    C        90        3    0
# 50                       Nutri-grain Wheat   K    C        90        3    0
# 9                              Bran Flakes   P    C        90        3    0
# 68                 Strawberry Fruit Wheats   N    C        90        2    0
# ...

# %%
cer['rating'].max()
# Out:
# 93.704912

# %%
cer['calories'].median()
# Out:
# 110.0

# %%
cer['calories'].std()
# Out:
# 19.48411905682084

# %%
cer['sodium'].min()
# Out:
# 0

# %%
cer.dtypes
# Out:
# name         object
# mfr          object
# type         object
# calories      int64
# protein       int64
# fat           int64
# sodium        int64
# fiber       float64
# carbo       float64
# sugars        int64
# potass        int64
# vitamins      int64
# shelf         int64
# weight      float64
# cups        float64
# rating      float64
# dtype: object

# %%
cer.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
cer['weight']
# Out:
# 0     1.00
# 1     1.00
# 2     1.00
# 3     1.00
# 4     1.00
# 5     1.00
# 6     1.00
# 7     1.33
# 8     1.00
# 9     1.00
# 10    1.00
# 11    1.00
# 12    1.00
# 13    1.00
# 14    1.00
# 15    1.00
# 16    1.00
# 17    1.00
# 18    1.00
# 19    1.00
# 20    1.00
# 21    1.00
# 22    1.00
# 23    1.00
# 24    1.00
# 25    1.00
# 26    1.00
# 27    1.25
# 28    1.33
# 29    1.00
#       ...
# 47    1.00
# 48    1.00
# 49    1.33
# 50    1.00
# 51    1.25
# 52    1.33
# 53    1.00
# 54    0.50
# 55    0.50
# 56    1.00
# 57    1.00
# 58    1.33
# 59    1.00
# 60    1.00
# 61    1.00
# 62    1.00
# 63    0.83
# 64    1.00
# 65    1.00
# 66    1.00
# 67    1.00
# 68    1.00
# 69    1.00
# 70    1.50
# 71    1.00
# 72    1.00
# 73    1.00
# 74    1.00
# 75    1.00
# 76    1.00
# Name: weight, Length: 77, dtype: float64

# %%
cer['weightounch']=cer['weight']*28.3495

# %%
cer.head(5)
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843
#
#    weightounch
# 0      28.3495
# 1      28.3495
# 2      28.3495
# 3      28.3495
# 4      28.3495

# %%
cer[(cer['protein']>3 ) & (cer['sugars']<5 )]
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 11                   Cheerios   G    C       110        6    2     290    2.0
# 43                      Maypo   A    H       100        4    1       0    0.0
# 57             Quaker Oatmeal   Q    H       100        5    2       0    2.7
# 67                  Special K   K    C       110        6    0     230    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 11   17.0       1     105        25      1     1.0  1.25  50.764999
# 43   16.0       3      95        25      2     1.0  1.00  54.850917
# 57   -1.0      -1     110         0      1     1.0  0.67  50.828392
# 67   16.0       3      55        25      1     1.0  1.00  53.131324
#
#     weightounch
# 3       28.3495
# 11      28.3495
# 43      28.3495
# 57      28.3495
# ...

# %%
cer[(cer['shelf']==3) & (cer['fiber'])].max()
# Out:
# name           Total Whole Grain
# mfr                            R
# type                           C
# calories                     160
# protein                        4
# fat                            5
# sodium                       320
# fiber                         14
# carbo                         21
# sugars                        14
# potass                       330
# vitamins                     100
# shelf                          3
# weight                       1.5
# cups                           1
# rating                   93.7049
# weightounch              42.5242
# dtype: object

# %%
cer.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating', 'weightounch'],
#       dtype='object')

# %%
cer['calories'].mean()
# Out:
# 106.88311688311688

# %%
sug_max=cer['sugars'].max()

# %%
cer[cer['sugars']==sug_max]['name']
# Out:
# 30    Golden Crisp
# 66          Smacks
# Name: name, dtype: object

# %%
pro_max=cer['protein'].max()

# %%
cer[cer['protein']==pro_max][['mfr','name']]
# Out:
#    mfr       name
# 11   G   Cheerios
# 67   K  Special K

# %%
cer.groupby('mfr')['calories'].mean()
# Out:
# mfr
# A    100.000000
# G    111.363636
# K    108.695652
# N     86.666667
# P    108.888889
# Q     95.000000
# R    115.000000
# Name: calories, dtype: float64

# %%
fat_mn=cer.groupby('mfr')['fat'].mean().reset_index()

# %%
fat_mn.columns=['mfr','fat_mn']

# %%
fat_mn.min()
# Out:
# mfr              A
# fat_mn    0.166667
# dtype: object

# %%
plt.scatter(cer['sugars'],cer['calories'],s=5)
plt.xlabel('Sugar')
plt.ylabel('Calories')
plt.title('Sugar vs Calories')
# Out:
# Text(0.5, 1.0, 'Sugar vs Calories')

# %%
cer[(cer['protein']>3) & (cer['fiber']>5)]
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
#
#    weightounch
# 0      28.3495
# 2      28.3495
# 3      28.3495

# %%
def cereal_per(vitamins):
    if vitamins>50:
        return True
    else:
        return False

# %%
vit_check=cer['vitamins'].apply(lambda vitamins:cereal_per(vitamins))

# %%
vit_check.sum()/len(cer)*100
# Out:
# 7.792207792207792

# %%
sod_avg=cer['sodium'].mean()

# %%
cer[cer['sodium']<sod_avg]['name']
# Out:
# 0                             100% Bran
# 1                     100% Natural Bran
# 3             All-Bran with Extra Fiber
# 6                           Apple Jacks
# 13                             Clusters
# 17                            Corn Pops
# 19                   Cracklin' Oat Bran
# 20               Cream of Wheat (Quick)
# 22               Crispy Wheat & Raisins
# 24                          Froot Loops
# 26                  Frosted Mini-Wheats
# 29                       Fruity Pebbles
# 30                         Golden Crisp
# 32                    Grape Nuts Flakes
# 34                   Great Grains Pecan
# 41                                 Life
# 43                                Maypo
# 44     Muesli Raisins; Dates; & Almonds
# 45    Muesli Raisins; Peaches; & Pecans
# 46                 Mueslix Crispy Blend
# 54                          Puffed Rice
# 55                         Puffed Wheat
# 56                   Quaker Oat Squares
# ...

# %%
cer[(cer['rating']<50) & (cer['sugars']>15)]
# Out:
# Empty DataFrame
# Columns: [name, mfr, type, calories, protein, fat, sodium, fiber, carbo, sugars, potass, vitamins, shelf, weight, cups, rating, weightounch]
# Index: []

# %%
cer['shelf'].head(3)
# Out:
# 0    3
# 1    3
# 2    3
# Name: shelf, dtype: int64

# %%
cer[(cer['shelf']==1) & (cer['fat']<5)].head(5)
# Out:
#                        name mfr type  calories  protein  fat  sodium  fiber  \
# 5   Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 8                 Bran Chex   R    C        90        2    1     200    4.0
# 11                 Cheerios   G    C       110        6    2     290    2.0
# 15                Corn Chex   R    C       110        2    0     280    0.0
# 16              Corn Flakes   K    C       100        2    0     290    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 5    10.5      10      70        25      1     1.0  0.75  29.509541
# 8    15.0       6     125        25      1     1.0  0.67  49.120253
# 11   17.0       1     105        25      1     1.0  1.25  50.764999
# 15   22.0       3      25        25      1     1.0  1.00  41.445019
# 16   21.0       2      35        25      1     1.0  1.00  45.863324
#
#     weightounch
# 5       28.3495
# 8       28.3495
# 11      28.3495
# 15      28.3495
# ...

# %%
cer.groupby('shelf')['calories'].sum()
# Out:
# shelf
# 1    2050
# 2    2300
# 3    3880
# Name: calories, dtype: int64

# %%
cer.groupby('vitamins')['rating'].mean()
# Out:
# vitamins
# 0      61.077283
# 25     40.762713
# 100    38.098352
# Name: rating, dtype: float64

# %%
cer['s/c']=cer['sugars']/cer['calories']

# %%
cer['s/c'].head(3)
# Out:
# 0    0.085714
# 1    0.066667
# 2    0.071429
# Name: s/c, dtype: float64

# %%
cer.head(3)
# Out:
#                 name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 0          100% Bran   N    C        70        4    1     130   10.0    5.0
# 1  100% Natural Bran   Q    C       120        3    5      15    2.0    8.0
# 2           All-Bran   K    C        70        4    1     260    9.0    7.0
#
#    sugars  potass  vitamins  shelf  weight  cups     rating  weightounch  \
# 0       6     280        25      3     1.0  0.33  68.402973      28.3495
# 1       8     135         0      3     1.0  1.00  33.983679      28.3495
# 2       5     320        25      3     1.0  0.33  59.425505      28.3495
#
#         s/c
# 0  0.085714
# 1  0.066667
# 2  0.071429
